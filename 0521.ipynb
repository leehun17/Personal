# %% [markdown]
# # 프로젝트명: 데이터 수집 실습 1 (BeautifulSoup4)
#
# #### 📌 BeautifulSoup는 정적인 사이트 수집에 주로 사용되며, html 태그의 데이터들을 가져옵니다.
# - BeautifulSoup - 정적, Selenium - 동적
# - BeautifulSoup의 단점은 웹 페이지에 스크롤로 움직여야지 데이터가 나오는 구조에선 사용하기 어렵습니다.
#
# #### 🚨 주의사항
# - 데이터 수집을 싫어하는 사이트의 정책 존중하기
# - 많은 요청은 서버에서 차단할 수 있으니, time.sleep(5) 실행해서 서버 과부하 예방하기

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### 1. requests로 데이터 가져오기

# %% [markdown]
# https://weworkremotely.com/remote-full-time-jobs

# %%
url = "https://weworkremotely.com/remote-full-time-jobs"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# https://developer.mozilla.org/ko/docs/Web/HTTP/Status/200
# MDN Web DocsMDN Web Docs
# 200 OK - HTTP | MDN
# HTTP 200 OK 는 요청이 성공했음을 나타내는 성공 응답 상태 코드입니다. 200 응답은 기본적으로 캐시 가능합니다. (24kB)

# %%
## 해당 URL을 요청했을때 정상적으로 응답이 왔는지 확인
if response.status_code == 200:
    print("성공")
else :
    print("실패")
# Out:
# 성공

# %%
response.url
# Out:
# 'https://weworkremotely.com/remote-full-time-jobs'

# %% [markdown]
# ### 2. BS4 사용하기

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
response.content
# Out:
# b'<!DOCTYPE html><html><head><meta charset=utf-8 /><script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"f7ae79e7ca","applicationID":"192262830","transactionName":"d1gPFhEMXVVWQxwKC0dDCAwEEB5fRl1fORZdWgQ9DwpCTVpfVBU=","queueTime":2,"applicationTime":252,"agent":""}</script><script>(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"f7ae79e7ca",applicationID:"192262830"};;/*! For license information please see nr-loader-rum-1.260.0.min.js.LICENSE.txt */\n(()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>v,Mt:()=>b,C5:()=>s,OP:()=>k,lF:()=>P,Yu:()=>_,Dg:()=>m,CX:()=>c,GE:()=>w,sU:()=>N});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",g=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. \'*\' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},soft_navigations:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},h="All configuration objects require an agent identifier!";function v(e){if(!e)throw new Error(h);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function m(e,t){if(!e)throw new Error(h);p[e]=(0,i.D)(t,g());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e,t){if(!e)throw new Error(h) ...

# %%
soup
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><script>window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"f7ae79e7ca","applicationID":"192262830","transactionName":"d1gPFhEMXVVWQxwKC0dDCAwEEB5fRl1fORZdWgQ9DwpCTVpfVBU=","queueTime":2,"applicationTime":252,"agent":""}</script><script>(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"f7ae79e7ca",applicationID:"192262830"};;/*! For license information please see nr-loader-rum-1.260.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={234:(e,t,r)=>{"use strict";r.d(t,{P_:()=>v,Mt:()=>b,C5:()=>s,OP:()=>k,lF:()=>P,Yu:()=>_,Dg:()=>m,CX:()=>c,GE:()=>w,sU:()=>N});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o);const r=(0,n.ek)(e);r&&(r.info=a[e])}const u=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(7056),l=r(50);const f="[data-nr-mask]",g=()=>{const e={mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{feature_flags:[],proxy:{assets:void 0,beacon:void 0},privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10,autoStart:!0},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{expiresMs:d.oD,inactiveMs:d.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},metrics:{enabled:!0,autoStart:!0},page_action:{enabled:!0,harvestTimeSeconds:30,autoStart:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1,autoStart:!0},session_trace:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},harvest:{tooManyRequestsDelay:60},session_replay:{autoStart:!0,enabled:!1,harvestTimeSeconds:60,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,inline_stylesheet:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){u(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,l.Z)("An invalid session_replay.mask_selector was provided. '*' will be used.",t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){u(t)?e.block_selector+=",".concat(t):""!==t&&(0,l.Z)("An invalid session_replay.block_selector was provided and will not be used",t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,l.Z)("An invalid session_replay.mask_input_option was provided and will not be used",t)}},spa:{enabled:!0,harvestTimeSeconds:10,autoStart:!0},soft_navigations:{enabled:!0,harvestTimeSeconds:10,autoStart:!0}}},p={},h="All configuration objects require an agent identifier!";function v(e){if(!e)throw new Error(h);if(!p[e])throw new Error("Configuration for ".concat(e," was never set"));return p[e]}function m(e,t){if(!e)throw new Error(h);p[e]=(0,i.D)(t,g());const r=(0,n.ek)(e);r&&(r.init=p[e])}function b(e,t){if(!e)throw new Error(h);var r=v(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const y={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},A={};function w(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");A[e]=(0,i.D)(t,y);const r=(0,n.ek)(e);r&&(r.loader_config=A[e])}const _=(0,n.mF)().o;var E=r(385),x=r(6818);const D={buildEnv:x.Re,distMethod:x.gF,version:x.q4,originTime:E.sK},S={customTransaction:void 0,disabled:!1,isolatedBacklog:!1,loaderType:void 0,maxBy ...
#   {
#     "@context": "http://schema.org",
#     "@type": "Organization",
#     "name": "We Work Remotely",
#     "url": "https://weworkremotely.com",
#     "logo": "https://weworkremotely.com/assets/wwr-social-fd7d545c56e975b65fae9cf49346aac95a8cdb4774b2c269af89ac8993141380.png",
#     "sameAs": [
#       "https://twitter.com/weworkremotely"
#     ]
#   }
#   </script><script type="application/ld+json">
#   {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "name": "We Work Remotely",
#     "url": "https://weworkremotely.com",
#     "potentialAction": {
#       "@type": "SearchAction",
#       "target": "https://weworkremotely.com/jobs/search?term={search_term_string}",
#       "query-input": "required name=search_term_string"
#     }
#   }
#   </script><link href="/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/manifest.json" rel="manifest"/><meta content="#212529000" name="msapplication-TileColor"/><meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#212529000" name="theme-color"/><meta content="authenticity_token" name="csrf-param"><meta content="uCpR4+QpKydvzxh7BYIsO1+3sl5bWoEehGdGyFDx0ISgOTGmXHq90tWhOr4NxX6oTtsBvtBWJyE3EZVY5LJiyg==" name="csrf-token"><link href="https://weworkremotely.com/remote-jobs.rss" rel="alternate" title="RSS" type="application/rss+xml"><link href="https://weworkremotely.com/remote-full-time-jobs" rel="canonical"><script>
#   window._tfa = window._tfa || [];
#   window._tfa.push({notify: 'event', name: 'page_view', id: 1219634});
#   !function (t, f, a, x) {
#          if (!document.getElementById(x)) {
#             t.async = 1;t.src = a;t.id=x;f.parentNode.insertBefore(t, f);
#          }
#   }(document.createElement('script'),
#   document.getElementsByTagName('script')[0],
#   '//cdn.taboola.com/libtrc/unip/1219634/tfa.js',
#   'tb_tfa_script');
# </script><noscript><img height="0" src="//trc.taboola.com/1219634/log/3/unip?en=page_view" style="display:none" width="0"/></noscript><script async="" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js"></script><script>
#     var OneSignal = window.OneSignal || [];
#         OneSignal.push(["init", {
#             appId: "3ac5a7b6-b83c-4a52-aaf2-02be475503c5",
#             autoRegister: false,
#             notifyButton: {
#                 enable: false
#             },
#           persistNotification: false
#         }]);
#     </script><script>(function(w,r){w._rwq=r;w[r]=w[r]||function(){(w[r].q=w[r].q||[]).push(arguments)}})(window,'rewardful');</script><script async="" data-rewardful="15c623" src="https://r.wdfl.co/rw.js"></script><script>
#     (function(h,o,t,j,a,r){
#       h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#       h._hjSettings={hjid:2385808,hjsv:6};
#       a=o.getElementsByTagName('head')[0];
#       r=o.createElement('script');r.async=1;
#       r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv;
#       a.appendChild(r);
#     })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
# 	</script><script async="" src="https://script.tapfiliate.com/tapfiliate.js"></script><script>
#     (function(t,a,p){t.TapfiliateObject=a;t[a]=t[a]||function(){
#     (t[a].q=t[a].q||[]).push(arguments)}})(window,'tap');
#
#     tap('create', '26060-8d5b8b', { integration: "stripe" });
#     tap('detect');
#   </script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-HFDNXM8BDG"></script><script>
#     window.dataLayer = window.dataLayer || [];
#     function gtag(){dataLayer.push(arguments);}
#     gtag('js', new Date());
#
#     gtag('config', "G-HFDNXM8BDG");
#   </script><script>
# //<![CDATA[
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#     ga('create', 'UA-24041469-10', 'auto');
#     ga('require', 'GTM-WFH9SJ4');
#     ga('send', 'pageview');
# //]]>
# </script><script>
# //<![CDATA[
# (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#    h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#    (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#    })(window,document.documentElement,'async-hide','dataLayer',4000,
#    {'GTM-WFH9SJ4':true});
# //]]>
# </script><script>
# //<![CDATA[
# if(window.ga != undefined){ga('send', 'pageview');}
# //]]>
# </script><script crossorigin="anonymous" src="https://kit.fontawesome.com/db1101d7e0.js"></script><script src="https://js.stripe.com/v3/"></script></link></link></meta></meta></meta></meta></head><body class="home"><div class=".container--wwr"><link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" rel="stylesheet"/><script crossorigin="anonymous" integrity="sha256-/JqT3SQfawRcv/BIHPThkBvs0OEvtFFmqPF/lYI/Cxo=" src="https://code.jquery.com/jquery-3.7.1.min.js"></script><script crossorigin="anonymous" integrity="sha384-I7E8VVD/ismYTF4hNIPjVp/Zjvgyol6VFvRkX/vR+Vc4jQkC+hVqc2pM8ODewa9r" src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.11.8/dist/umd/popper.min.js"></script><script crossorigin="anonymous" integrity="sha384-Rx+T1VzGupg4BHQYs2gCW9It+akI2MM/mndMCy36UVfodzcJcF0GGLxZIzObiEfa" src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/js/bootstrap.min.js"></script><header id="nav-header"><section id="header-top-bar"><a href="/"><img alt="we work remotely" id="logo" src="https://weworkremotely.com/assets/IsotypeV2-1ebe3dd57673f3e8d02b7490bc0faaef55d6a95d3a4aaf17298bd3ed503ae7fe.svg"/></a><nav class="top"><div class="dropdownBackground"><span class="arrow"></span></div><ul class="wwr__nav"><li class="magic__nav"><a href="#">Categories</a><ul class="dropdown categories"><li class="dropdown-programming"><a href="#" id="programming-active">Programming <i class="fa fa-chevron-down"></i></a></li><div class="dropdown-container"><li><a href="/categories/remote-full-stack-programming-jobs#job-listings">Full-Stack Programming</a></li><li><a href="/categories/remote-front-end-programming-jobs#job-listings">Front-End Programming</a></li><li><a href="/categories/remote-back-end-programming-jobs#job-listings">Back-End Programming</a></li></div><li><a href="/categories/remote-design-jobs#job-listings">Design</a></li><li><a href="/categories/remote-devops-sysadmin-jobs#job-listings">Devops and Sysadmin</a></li><li><a href="/categories/remote-management-and-finance-jobs#job-listings">Management and Finance</a></li><li><a href="/categories/remote-product-jobs">Product</a></li><li><a href="/categories/remote-customer-support-jobs#job-listings">Customer Support</a></li><li><a href="/categories/remote-sales-and-marketing-jobs#job-listings">Sales and Marketing</a></li><li><a href="/remote-full-time-jobs#job-listings">Full-Time</a></li><li><a href="/remote-contract-jobs#job-listings">Contract</a></li><li><a href="/categories/all-other-remote-jobs#job-listings">All Other</a></li></ul></li><li class="magic__nav"><a href="#">Community</a><ul class="dropdown community"><li><a href="/blog">Blog</a></li><li><a href="/the-remote-show-podcast">Podcast</a></li><hr/><li><a href="https://mailchi.mp/weworkremotely/newsletter" target="_blank">Newsletter</a></li><li><a href="https://bit.ly/wwrslack2021" target="_blank">Slack</a></li><li><a href="/blog-categories/events" target="_blank">Events</a></li><hr/><li><a href="https://twitter.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-twitter&amp;utm_medium=nav-network-twitter" target="_blank">Twitter</a></li><li><a href="https://www.instagram.com/weworkremotelycom/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">Instagram</a></li><li><a href="https://www.linkedin.com/company/18527028/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-linkedin&amp;utm_medium=nav-network-linkedin" target="_blank">Linkedin</a></li><li><a href="https://www.facebook.com/weworkremotely/?utm_content=nav-network&amp;utm_source=we-work-remotely&amp;utm_campaign=nav-network-fb&amp;utm_medium=nav-network-fb" target="_blank">Facebook</a></li></ul></li><li class="magic__nav"><a href="#">Job Seekers</a><ul class="dropdown resources"><l ...
#   function closeButton() {
#     document.getElementById('close_flash').style.display = 'none';
#   }
#   function closeButtonError() {
#     document.getElementById('error_explanation').style.display = 'none';
#   }
#   function closeButtonFlashError() {
#     document.getElementById('close_error').style.display = 'none';
#   }
# </script></div><script>
#   function ResetFilters() {
#     var url = window.location.href.split('?')[0];
#     setTimeout(function(){
#       window.location.href = url;
#     }, 100);
#   }
# </script><div class="content-wrap"><h1 class="categories-header" style="margin: 190px auto -60px auto;line-height: 3.5rem;"><a href="/"> Remote Full-Time Jobs </a></h1></div><section class="content-wrap" id="intro"><p class="secondary-feature">Ready to jump into full-time remote work (aka you’ve mastered the art of making your top half presentable for video calls)? You’ve come to the right place! Find all full-time remote jobs below.</p></section></header><a class="anchor-offset" id="job-listings">・</a><section id="banner-header"><div class="trusted_banner"><div id="trusted-text">Trusted by the world's leading companies</div></div></section><div class="jobs-container" id="job_list"><section class="jobs"><article><h2> All Remote Full-Time Jobs <span class="latest_post">Latest post about 7 hours ago</span></h2><ul><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/lemon-io"><div alt="Lemon.io is hiring a remote Senior
">Events</a><br/><a href="/remote-job-rss-feed">RSS</a><br/><a href="/terms-and-conditions">Terms</a><br/><a href="/privacy">Privacy</a><br/><a href="/community-guidelines">Guidelines</a><br/><a href="/post-a-remote-job">Why Choose WWR?</a><br/><br/><b id="total">32,556</b><b id="jobs-posted"> Remote jobs posted</b><br/><br/><br/><li><a class="footer-icons" href="https://www.facebook.com/weworkremotely/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-fb&amp;utm_medium=footer-network-fb" target="_blank"><img src="https://weworkremotely.com/assets/facebook-531b7d41f88457036d693d70cee1998c8b7b115b52e1781fc4428a9a4f5121b5.svg"/></a><a class="footer-icons" href="https://www.linkedin.com/company/18527028/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-linkedin&amp;utm_medium=footer-network-linkedin" target="_blank"><img src="https://weworkremotely.com/assets/linkedin-23a8cd96172f54a738a48100b505c83df01f4b7da7e76da6fecf879c8f04bbc3.svg"/></a><a class="footer-icons" href="https://www.instagram.com/weworkremotelycom/?hl=en&amp;utm_campaign=footer-network-ig&amp;utm_medium=footer-network-ig" target="_blank"><img src="https://weworkremotely.com/assets/instagram-6c8dd853a0bc5b5deae9f1dddc4c58ada52dbde23142a57a0d466f42661a8af3.svg"/></a><a class="footer-icons" href="https://twitter.com/weworkremotely/?utm_content=footer-network&amp;utm_source=we-work-remotely&amp;utm_campaign=footer-network-twitter&amp;utm_medium=footer-network-twitter" target="_blank"><img src="https://weworkremotely.com/assets/twitter-80a6bef32a881252b35f7bd488d3f7d3d87a44ff6540b62d4fe44269ff350585.svg"/></a><a class="footer-icons" href="https://bit.ly/wwrslack2021" target="_blank"><img src="https://weworkremotely.com/assets/slack-4341aece3e5f2e7355d24ea1511138358d2d179930af8a4b589fdc5a4cc66ec7.svg"/></a></li><br/><br/><li id="copyright"> Copyright © 2024 <span id="mobile-break"><br/><br/></span><span id="mobile-bull"></span></li></br></br></br></br></div></br></p></br></br></br></br></div><div id="footer-right"><p id="listings-total"><b id="total">32,556</b><br><b id="jobs-posted">Remote jobs posted<br/></b><a href="/remote-jobs/new" id="job-cta-alt">Post a job for $299</a><br><br><br><br><br><a href="#" style="color: #FFFFFF;font-size: 1em;">Back to top ↑</a></br></br></br></br></br></br></p></div><div id="footer-right" style="margin-right: 42px;"> ...
#   tippy('.clip-btn', {
#     content: "Email Copied to Clipboard!",
#     placement: 'top',
#     animation: 'fade',
#     trigger: 'click',
#     delay: 50,
#     // onShow(instance) {
#     //   setTimeout(() => {
#     //     instance.hide();
#     //   }, 5000);
#     // }
#   });
# </script><script src="https://weworkremotely.com/assets/application-97e413cd5b628755753e57902ce8aab4d2600e3a896d611cc6e8dbb94ca61edd.js"></script><script async="">adroll_adv_id="ACJ6YJHXKNBNJBSFTNFVOF",adroll_pix_id="W4DPE7ODW5E3BKBBL3VPMG",adroll_email="matt@tinyboards.co",function(){var t=function(){if(!document.readyState||/loaded|complete/.test(document.readyState)){if(!window.__adroll_loaded)return __adroll_loaded=!0,void setTimeout(t,50);var e=document.createElement("script"),d="https:"==document.location.protocol?"https://s.adroll.com":"http://a.adroll.com";e.setAttribute("async","true"),e.type="text/javascript",e.src=d+"/j/roundtrip.js",((document.getElementsByTagName("head")||[null])[0]||document.getElementsByTagName("script")[0].parentNode).appendChild(e)}else setTimeout(t,10)};window.addEventListener?window.addEventListener("load",t,!1):window.attachEvent("onload",t)}();</script><script async="">
# !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
# },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
# a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
# // Insert Twitter Pixel ID and Standard Event data below
# twq('init','nzx8k');
# twq('track','PageView');
# </script><script> _linkedin_partner_id = "663722"; window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || []; window._linkedin_data_partner_ids.push(_linkedin_partner_id); </script><script> (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})(); </script><noscript><img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=663722&amp;fmt=gif" style="display:none;" width="1"/></noscript><script crossorigin="anonymous" integrity="sha512-rMGGF4wg1R73ehtnxXBt5mbUfN9JUJwbk21KMlnLZDJh7BkPmeovBuddZCENJddHYYMkCh9hPFnPmS9sspki8g==" src="https://cdnjs.cloudflare.com/ajax/libs/chosen/1.8.7/chosen.jquery.min.js"></script><script>
#   jQuery(document).ready(function () {
#     var chosenOpen = false;
#     jQuery(".chosen").chosen();
#     jQuery('.outsider-select').append('<span class="closeChosen"></span>');
#     jQuery(document).on('click', '.closeChosen', function (e) {
#       var chosenEle = jQuery(this).parents('.outsider-select').find('.chosen-container');
#       if (chosenEle.hasClass('chosen-with-drop') && chosenEle.hasClass('chosen-container-active')) {
#         jQuery(this).parents('.outsider-select').find('select').trigger('chosen:close');
#       } else {
#         jQuery(this).parents('.outsider-select').find('select').trigger('chosen:open');
#       }
#     });
#
#     // Warning - Library is no longer maintained, refer: https://github.com/bbarakaci/fixto
#     // Update Library to https://cdnjs.com/libraries/stickybits
#     var stickyEl = jQuery('#advanced_search_filters').fixTo('#side_filter_column', {
#       top: 100,
#       mindBottomPadding: true
#     });
#   });
# </script></br></body></html>

# %% [markdown]
# ### 2-1. BS 주요 메소드
# - find : 정의한 요소 1개만 찾아줍니다.
# - find_all : 정의한 요소들을 다 찾아줍니다.
#
# ![태그의클래스](https://file.notion.so/f/f/4e4750b9-2973-47f2-9fe5-8330ce1f2c19/6fc7e475-b001-44df-a496-121d3d506968/%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA_2024-05-21_%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB_6.42.27.png?id=6b7322b7-4d70-4722-b7ee-ecbd0a3ec2ac&table=block&spaceId=4e4750b9-2973-47f2-9fe5-8330ce1f2c19&expirationTimestamp=1716328800000&signature=4NAiaIoGcyPep2pY3unz-Rqv1yKlP0iJJAqzFeMnwrs&downloadName=%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA+2024-05-21+%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB+6.42.27.png)

# %%
item_table = soup.find('section', class_='jobs')

# %%
item_table
# Out:
# <section class="jobs"><article><h2> All Remote Full-Time Jobs <span class="latest_post">Latest post about 7 hours ago</span></h2><ul><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/lemon-io"><div alt="Lemon.io is hiring a remote Senior Java Full-stack Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0076/3337/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Senior Java Full-stack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36438" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="Dq10EjAOJs/c6LHjybwnBHssgjMC+zMIJHDjdvnDvzIwGHSrEnrMt9bBvBSLEpAQRQWYN/PIWio/RQNdUgS8WQ=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class= ...
#   // When the modal is clicked
#   document.querySelector('.clickable-element').addEventListener('click', function() {
#       document.querySelector('#nav-header').style.display = 'none';
#   });
#
#   // When the modal is closed
#   document.querySelector('.modal').addEventListener('hidden.bs.modal', function () {
#       document.querySelector('#nav-header').style.display = 'block';
#   });
# </script><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/rebelcode"><div alt="RebelCode is hiring a remote Lead Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5301/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/rebelcode-lead-developer"><span class="company">RebelCode</span><br/><span class="title">Lead Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li><script>
#   // When the modal is clicked
#   document.querySelector('.clickable-element').addEventListener('click', function() {
#       document.querySelector('#nav-header').style.display = 'none';
#   });
#
#   // When the modal is closed
#   document.querySelector('.modal').addEventListener('hidden.bs.modal', function () {
#       document.querySelector('#nav-header').style.display = 'block';
#   });
# </script><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Full Stack Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-full-stack-developer-remote-saas-m-f-d"><span class="company">SocialHub</span><br/><span class="title">Full Stack Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li><script>
#   // When the modal is clicked
#   document.querySelector('.clickable-element').addEventListener('click', function() {
#       document.querySelector('#nav-header').style.display = 'none';
#   });
#
#   // When the modal is closed
#   document.querySelector('.modal').addEventListener('hidden.bs.modal', function () {
#       document.querySelector('#nav-header').style.display = 'block';
#   });
# </script><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-backend-javascript-node-js-developer-remote-saas-m-f-d-3"><span class="company">SocialHub</span><br/><span class="title">Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li><script>
#   // When the modal is clicked
#   document.querySelector('.clickable-element').addEventListener('click', function() {
#       document.querySelector('#nav-header').style.display = 'none';
#   });
#
#   // When the modal is closed
#   document.querySelector('.modal').addEventListener('hidden.bs.modal', function () {
#       document.querySelector('#nav-header').style.display = 'block';
#   });
# </script><li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/burnette-dobson-pinchak"><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs
time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">USA Only</span></a></li><script>
#   // When the modal is clicked
#   document.querySelector('.clickable-element').addEventListener('click', function() {
#       document.querySelector('#nav-header').style.display = 'none';
#   });
#
#   // When the modal is closed
#   document.querySelector('.modal').addEventListener('hidden.bs.modal', function () {
#       document.querySelector('#nav-header').style.display = 'block';
#   });
# </script><li><a class="view-all" href="/">← Back to all jobs</a></li></ul><br><br><p><div aria-label="pager" class="pagination" role="navigation"><span class="pages-container with_next_last"><span class="page current"> 1 </span><span class="page"><a href="/remote-full-time-jobs?page=2" rel="next">2</a></span><span class="page"><a href="/remote-full-time-jobs?page=3">3</a></span></span><span class="next"><a href="/remote-full-time-jobs?page=2" rel="next">&gt;</a></span><span class="last"><a href="/remote-full-time-jobs?page=3">LAST</a></span></div><br/><br/></p></br></br></article></section>

# %%
item_table.find_all('li', class_='feature')
# Out:
# [<li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/lemon-io"><div alt="Lemon.io is hiring a remote Senior Java Full-stack Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0076/3337/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Senior Java Full-stack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36438" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="Dq10EjAOJs/c6LHjybwnBHssgjMC+zMIJHDjdvnDvzIwGHSrEnrMt9bBvBSLEpAQRQWYN/PIWio/RQNdUgS8WQ=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="ba ...
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/rebelcode"><div alt="RebelCode is hiring a remote Lead Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5301/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/rebelcode-lead-developer"><span class="company">RebelCode</span><br/><span class="title">Lead Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Full Stack Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-full-stack-developer-remote-saas-m-f-d"><span class="company">SocialHub</span><br/><span class="title">Full Stack Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-backend-javascript-node-js-developer-remote-saas-m-f-d-3"><span class="company">SocialHub</span><br/><span class="title">Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/burnette-dobson-pinchak"><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/burnette-dobson-pinchak-executive-assitant-to-the-ceo"><span class="company">BURNETTE, DOBSON &amp; PINCHAK</span><br/><span class="title">Executive Assitant to the CEO</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/picklebali"><div alt="PickleBali is hiring a remote Technical Apparel Designer - Help Design Unique Sports Apparel using CLO3D, Browzwear, Marvelous at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5265/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/picklebali-technical-apparel-designer-help-design-unique-sports-apparel-using-clo3d-browzwear-marvelous"><span class="company">PickleBali</span><br/><span class="title">Technical Apparel Designer - Help Design Unique Sports Apparel using CLO3D, Browzwear, Marvelous</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Europe Only/UK Only/EMEA Only/Asia Only/Oceania Only</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/elite-software-automation"><div alt="Elite Software Automation is hiring a remote Business Analyst at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0083/7653/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/elite-software-automation-business-analyst"><span class="company">Elite Software Automation</span><br/><span class="title">Business Analyst</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/a5-labs"><div alt="A5 Labs is hiring a remote Head of Cloud Operations at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5236/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/a5-labs-head-of-cloud-operations"><span class="company">A5 Labs</span><br/><span class="title">Head of Cloud Operations</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Europe Only/UK Only</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/yoko-co"><div alt="Yoko Co is hiring a remote UI/Web Designer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0018/9650/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/yoko-co-ui-web-designer"><span class="company">Yoko Co</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">UI/Web Designer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/medusa"><div alt="Medusa is hiring a remote Senior Software Engineer | Ecommerce dev-tool startup at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0133/3822/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/medusa-senior-software-engineer-ecommerce-dev-tool-startup"><span class="company">Medusa</span><br/><span class="title">Senior Software Engineer | Ecommerce dev-tool startup</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/clouddevs"><div alt="CloudDevs is hiring a remote React/Node Fullstack Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0081/8410/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">CloudDevs</span><br/><span class="title">React/Node Fullstack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only/Asia Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=35750" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="spL91GqChKw4QlxT8DtgcKrPUzl/xlx863XME8wrweeMJ/1tSPZu1DJrUaSylddklOZJPY71NV7wQCw4Z+zCjA=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">CloudDevs</span><br/><span class="title">React/Node Fullstack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only/Asia Only</span></a></div></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/circuit"><div alt="Circuit is hiring a remote Senior Web Developer - Support Team - Remote at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0134/4096/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/circuit-senior-web-developer-support-team-remote"><span class="company">Circuit</span><br/><span class="title">Senior Web Developer - Support Team - Remote</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company"></span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company
developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/proxify-ab"><div alt="Proxify AB is hiring a remote Senior MS Power BI Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0084/0935/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Proxify AB</span><br/><span class="title">Senior MS Power BI Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36285" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="ruLySabJBlhZ4tSyj+JMNj0P1jPlZvKrvXz/z8KlIAqQV/LwhL3sIFPL2UXNTPsiAybMNxRVm4mmSR/kaWIjYQ=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">Proxify AB</span><br/><span class="title">Senior MS Power BI Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only</span></a></div></li>,
# ...
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/proxify-ab"><div alt="Proxify AB is hiring a remote Senior Flutter Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0084/0935/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Proxify AB</span><br/><span class="title">Senior Flutter Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36276" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="AuRbCK502XwHG1cnIcYBrtIqTPRyi05LXf3HWxlc/cM8UVuxjAAzBA0yWtBjaLa67ANW8IO4J2lGyCdwspv+qA=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">Proxify AB</span><br/><span class="title">Senior Flutter Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/EMEA Only</span></a></div></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/storyteller"><div alt="Storyteller is hiring a remote Delivery Manager at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0082/2080/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/storyteller-delivery-manager"><span class="company">Storyteller</span><br/><span class="title">Delivery Manager</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">USA Only/Europe Only/UK Only/Canada Only</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/baymard-institute"><div alt="Baymard Institute is hiring a remote Head of B2B Growth Marketing/Demand Generation at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0001/6931/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/baymard-institute-head-of-b2b-growth-marketing-demand-generation"><span class="company">Baymard Institute</span><br/><span class="title">Head of B2B Growth Marketing/Demand Generation</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/localize"><div alt="Localize is hiring a remote Platform Reliability Engineer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0017/1647/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/localize-platform-reliability-engineer"><span class="company">Localize</span><br/><span class="title">Platform Reliability Engineer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">USA Only</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/g2i-inc"><div alt="G2i Inc. is hiring a remote Backend Go Developer - Remote at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0001/4098/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">G2i Inc.</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Backend Go Developer - Remote</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=34123" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="YkvWCpGPj+Qz/Ph4/J/slX/l2EI/z8BrIsnzVrqY8zFc/tazs/tlnDnV9Y++MVuBQczCRs78qUk5/BN9EV/wWg=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">G2i Inc.</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Backend Go Develop ...
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/vidalytics"><div alt="Vidalytics is hiring a remote Customer Happiness Lead (SaaS Tech Support) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0123/5841/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/vidalytics-customer-happiness-lead-saas-tech-support"><span class="company">Vidalytics</span><br/><span class="title">Customer Happiness Lead (SaaS Tech Support)</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-20T14:25:18Z">May 20</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Americas Only</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/userevidence"><div alt="UserEvidence is hiring a remote Senior Full-stack Engineer (Rails) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/4913/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/userevidence-senior-full-stack-engineer-rails-1"><span class="company">UserEvidence</span><br/><span class="title">Senior Full-stack Engineer (Rails)</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-18T13:52:46Z">May 18</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only</span></a></li>]

# %%
### BS4의 chaining을 이용하여 데이터 추출
jobs = soup.find('section', class_='jobs').find_all('li')[:-1]

# %%
jobs
# Out:
# [<li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/lemon-io"><div alt="Lemon.io is hiring a remote Senior Java Full-stack Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0076/3337/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Senior Java Full-stack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36438" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="Dq10EjAOJs/c6LHjybwnBHssgjMC+zMIJHDjdvnDvzIwGHSrEnrMt9bBvBSLEpAQRQWYN/PIWio/RQNdUgS8WQ=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="ba ...
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/rebelcode"><div alt="RebelCode is hiring a remote Lead Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5301/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/rebelcode-lead-developer"><span class="company">RebelCode</span><br/><span class="title">Lead Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Full Stack Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-full-stack-developer-remote-saas-m-f-d"><span class="company">SocialHub</span><br/><span class="title">Full Stack Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/socialhub"><div alt="SocialHub is hiring a remote Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0099/5705/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/socialhub-backend-javascript-node-js-developer-remote-saas-m-f-d-3"><span class="company">SocialHub</span><br/><span class="title">Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d)</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/burnette-dobson-pinchak"><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs
span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/localize"><div alt="Localize is hiring a remote Platform Reliability Engineer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0017/1647/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/localize-platform-reliability-engineer"><span class="company">Localize</span><br/><span class="title">Platform Reliability Engineer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">USA Only</span></a></li>,
#  <li class="feature"><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/g2i-inc"><div alt="G2i Inc. is hiring a remote Backend Go Developer - Remote at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0001/4098/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">G2i Inc.</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Backend Go Developer - Remote</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=34123" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="YkvWCpGPj+Qz/Ph4/J/slX/l2EI/z8BrIsnzVrqY8zFc/tazs/tlnDnV9Y++MVuBQczCRs78qUk5/BN9EV/wWg=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">G2i Inc.</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Backend Go Develop ...
#  <li class=""><span class="new">New</span><div class=""></div><div class="tooltip--flag-logo"><a href="/company/ventures-together"><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/ventures-together-senior-ea"><span class="company">Ventures Together</span><br/><span class="title">Senior EA</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-20T15:40:50Z">May 20</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Europe Only/UK Only/Africa Only</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/vidalytics"><div alt="Vidalytics is hiring a remote Customer Happiness Lead (SaaS Tech Support) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0123/5841/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/vidalytics-customer-happiness-lead-saas-tech-support"><span class="company">Vidalytics</span><br/><span class="title">Customer Happiness Lead (SaaS Tech Support)</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-20T14:25:18Z">May 20</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Americas Only</span></a></li>,
#  <li class=""><span class="new">New</span><div class=""></div><div class="tooltip--flag-logo"><a href="/company/fluro"><div alt="Fluro is hiring a remote Senior Infrastructure Engineer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/5304/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/fluro-senior-infrastructure-engineer"><span class="company">Fluro</span><br/><span class="title">Senior Infrastructure Engineer</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-20T14:09:48Z">May 20</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Europe Only</span></a></li>,
#  <li class=""><span class="new">New</span><div class=""></div><div class="tooltip--flag-logo"><a href="/company/great-good-venture-studio"><div alt="Great Good Venture Studio is hiring a remote Sales &amp; Client Manager for Relocation Agency (Thailand based role) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0133/3817/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/great-good-venture-studio-sales-client-manager-for-relocation-agency-thailand-based-role"><span class="company">Great Good Venture Studio</span><br/><span class="title">Sales &amp; Client Manager for Relocation Agency (Thailand based role)</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-19T12:38:12Z">May 19</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Anywhere in the World</span></a></li>,
#  <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/userevidence"><div alt="UserEvidence is hiring a remote Senior Full-stack Engineer (Rails) at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/4913/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/userevidence-senior-full-stack-engineer-rails-1"><span class="company">UserEvidence</span><br/><span class="title">Senior Full-stack Engineer (Rails)</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-18T13:52:46Z">May 18</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only</span></a></li>,
#  <li class=""><span class="new">New</span><div class=""></div><div class="tooltip--flag-logo"><a href="/company/greenlight-media-pte-ltd"><div alt="Greenlight Media Pte Ltd is hiring a remote Operations Manager at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0141/4912/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/greenlight-media-pte-ltd-operations-manager"><span class="company">Greenlight Media Pte Ltd</span><br/><span class="title">Operations Manager</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-18T13:40:59Z">May 18</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Europe Only/UK Only/Asia Only/Oceania Only</span></a></li>,
#  <li class=""><span class="new">New</span><div class=""></div><div class="tooltip--flag-logo"><a href="/company/web3-jobs"><span class="tooltiptext">View Company Profile</span></a></div><a href="/remote-jobs/web3-jobs-senior-ruby-on-rails-developer"><span class="company">Web3 Jobs</span><br/><span class="title">Senior Ruby on Rails Developer</span><span class="date"><time data-format="%b %e" data-local="time" datetime="2024-05-17T15:36:00Z">May 17</time></span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">USA Only</span></a></li>]

# %% [markdown]
# ### 3. 데이터 추출하기

# %%
jobs[0]
# Out:
# <li class="feature"><span class="new">New</span><div class="highlight-bar"></div><div class="tooltip--flag-logo"><a href="/company/lemon-io"><div alt="Lemon.io is hiring a remote Senior Java Full-stack Developer at We Work Remotely." class="flag-logo" loading="lazy" style="background-image:url(https://we-work-remotely.imgix.net/logos/0076/3337/logo.gif?ixlib=rails-4.0.0&amp;w=50&amp;h=50&amp;dpr=2&amp;fit=fill&amp;auto=compress)"></div><span class="tooltiptext">View Company Profile</span></a></div><div class="clickable-element d-none d-md-block" data-bs-target="#HomeApplyModal" data-bs-toggle="modal" onclick="trackModalClick()" style="cursor: pointer;"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="background: #dde0f4;">Top 100</span></a></object><br/><span class="title">Senior Java Full-stack Developer</span><span class="featured">featured</span><br/><span class="company">Full-Time</span><span>/</span><span class="region company">Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only</span></div><div aria-hidden="true" aria-labelledby="HomeApplyModalLabel" class="modal fade" id="HomeApplyModal" style="z-index: 9999; margin-top: -200px !important; width: 100%;" tabindex="-1"><div class="modal-dialog modal-lg modal-custom"><div class="modal-content"><div class="modal-header"><button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button"></button></div><div class="modal-body"><form accept-charset="UTF-8" action="/job-seekers/account?signup_redirect_listing_id=36438" class="new_job_seeker" id="new_job_seeker" method="post" name="newSignupForm"><input name="authenticity_token" type="hidden" value="Dq10EjAOJs/c6LHjybwnBHssgjMC+zMIJHDjdvnDvzIwGHSrEnrMt9bBvBSLEpAQRQWYN/PIWio/RQNdUgS8WQ=="/><div style="margin-right: -28px;"><h1 style="font-size: 1.9rem;"><span style="margin-left: -66px;margin-right: 20px;"></span>Sign up now and unlock all job access.</h1></div><br/><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_email">Email Address</label><input autocomplete="email" autofocus="autofocus" class="form-control" id="job_seeker_email" name="job_seeker[email]" placeholder="example@mail.com " required="required" type="email" value=""/></div></div></div><div class="row mb-3"><div class="col"><div class="field"><label for="job_seeker_password">Create password</label><input autocomplete="new-password" class="form-control" id="job_seeker_password" minlength="6" name="job_seeker[password]" placeholder="" required="required" type="password"/></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field"><button class="btn btn-primary" data-disable-with="Please Wait..." id="create-account-cta" name="button" onclick="trackModalAccountButtonClick()" type="submit">Create Job Seeker Account</button></div></div></div><div class="row mb-2"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service" style="color: #212529;font-size: 0.9rem;"> Already a member? <a href="/job-seekers/account/login" style="text-decoration:underline !important;display:inline;" target="_blank">Log in</a></span></div></div></div><div class="row mb-3"><div class="col text-center"><div class="field d-flex align-items-center justify-content-center"><span id="terms_of_service"> By creating an account you agree to our <a href="/terms-and-conditions" style="text-decoration:underline !important;display:inline;" target="_blank">Terms of Service</a> and <a href="/privacy" style="text-decoration:underline !important;display:inline;" target="_blank">Privacy Policy</a>.</span></div></div></div></form></div></div></div></div><div class="d-block d-md-none"><a href="/job-seekers/account/register"><span class="company">Lemon.io</span><object><a href="/top-remote-companies" style="display: inline-block;"><span class="listing-pill" style="bac ...

# %%
## 회사명
jobs[0].find('span', class_="company").text
# Out:
# 'Lemon.io'

# %%
## 제목
jobs[0].find('span', class_="title").text
# Out:
# 'Senior Java Full-stack Developer'

# %%
jobs[0].find_all("span", class_="company")[1].text
# Out:
# 'Full-Time'

# %%
jobs[0].find("span", class_="region").text
# Out:
# 'Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only'

# %%
jobs[1].find_all("a")[1]['href']
# Out:
# '/remote-jobs/rebelcode-lead-developer'

# %%
len(jobs)
# Out:
# 50

# %%
for job in jobs:
    company = job.find('span', class_="company").text
    title = job.find('span', class_="title").text
    work_type = job.find_all("span", class_="company")[1].text
    region = job.find("span", class_="region").text
    detail_url = job.find_all("a")[1]["href"]
    company_url = f"https://weworkremotely.com/{detail_url}"
    
    job_data = {
            'company': company,
            'title': title,
            'work_type' : work_type,
            'region': region,
            'company_url': company_url
        }
    print(job_data)
# Out:
# {'company': 'Lemon.io', 'title': 'Senior Java Full-stack Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only', 'company_url': 'https://weworkremotely.com//top-remote-companies'}
# {'company': 'RebelCode', 'title': 'Lead Developer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/rebelcode-lead-developer'}
# {'company': 'SocialHub', 'title': 'Full Stack Developer - Remote/SaaS (m/f/d)', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/socialhub-full-stack-developer-remote-saas-m-f-d'}
# {'company': 'SocialHub', 'title': 'Backend Javascript / Node.js Developer - Remote/SaaS (m/f/d)', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/socialhub-backend-javascript-node-js-developer-remote-saas-m-f-d-3'}
# {'company': 'BURNETTE, DOBSON & PINCHAK', 'title': 'Executive Assitant to the CEO', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/burnette-dobson-pinchak-executive-assitant-to-the-ceo'}
# {'company': 'PickleBali', 'title': 'Technical Apparel Designer - Help Design Unique Sports Apparel using CLO3D, Browzwear, Marvelous', 'work_type': 'Full-Time', 'region': 'Europe Only/UK Only/EMEA Only/Asia Only/Oceania Only', 'company_url': 'https://weworkremotely.com//remote-jobs/picklebali-technical-apparel-designer-help-design-unique-sports-apparel-using-clo3d-browzwear-marvelous'}
# {'company': 'Elite Software Automation', 'title': 'Business Analyst', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/elite-software-automation-business-analyst'}
# {'company': 'A5 Labs', 'title': 'Head of Cloud Operations', 'work_type': 'Full-Time', 'region': 'Europe Only/UK Only', 'company_url': 'https://weworkremotely.com//remote-jobs/a5-labs-head-of-cloud-operations'}
# {'company': 'Yoko Co', 'title': 'UI/Web Designer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/yoko-co-ui-web-designer'}
# {'company': 'Medusa', 'title': 'Senior Software Engineer | Ecommerce dev-tool startup', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/medusa-senior-software-engineer-ecommerce-dev-tool-startup'}
# {'company': 'CloudDevs', 'title': 'React/Node Fullstack Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only/Asia Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Circuit', 'title': 'Senior Web Developer - Support Team - Remote', 'work_type': 'Full-Time', 'region': '', 'company_url': 'https://weworkremotely.com//remote-jobs/circuit-senior-web-developer-support-team-remote'}
# {'company': 'WP All Import', 'title': 'WP All Import: SEO Strategist & Writer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/wp-all-import-wp-all-import-seo-strategist-writer'}
# {'company': 'Empire Flippers', 'title': 'Director of Operations', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/empire-flippers-director-of-operations'}
# {'company': 'GoTu (formerly TempMee)', 'title': 'Senior Backend Engineer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/gotu-formerly-tempmee-senior-backend-engineer'}
# {'company': 'Input Logic', 'title': 'Product Manager', 'work_type': 'Full-Time', 'region': 'Canada Only', 'company_url': 'https://weworkremotely.com//remote-jobs/input-logic-product-manager-2'}
# {'company': 'Fortune Writers Inc', 'title': 'Content Writer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'We Work Remotely', 'title': 'Executive Assistant for Latin America', 'work_type': 'Full-Time', 'region': 'Latin America Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Interaction Design Foundation', 'title': 'Senior PHP (Laravel) Developer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/interaction-design-foundation-senior-php-laravel-developer-1'}
# {'company': 'SportyBet', 'title': 'Customer Service PaaS Product Manager ', 'work_type': 'Full-Time', 'region': 'Europe Only', 'company_url': 'https://weworkremotely.com//remote-jobs/sportybet-customer-service-paas-product-manager'}
# {'company': 'Toggl', 'title': 'Senior Backend Engineer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/toggl-senior-backend-engineer-2'}
# {'company': 'We Work Remotely', 'title': 'Financial Controller', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'SportyBet', 'title': 'Senior EU Frontend Engineer ', 'work_type': 'Full-Time', 'region': 'Europe Only', 'company_url': 'https://weworkremotely.com//remote-jobs/sportybet-senior-eu-frontend-engineer'}
# {'company': 'CobbleWeb', 'title': 'Senior Front-End JS Engineer', 'work_type': 'Full-Time', 'region': 'Europe Only/Africa Only', 'company_url': 'https://weworkremotely.com//remote-jobs/cobbleweb-senior-front-end-js-engineer-1'}
# {'company': 'silverorange', 'title': 'Senior Web & App Designer', 'work_type': 'Full-Time', 'region': 'Canada Only', 'company_url': 'https://weworkremotely.com//remote-jobs/silverorange-senior-web-app-designer-1'}
# {'company': 'Interaction Design Foundation', 'title': 'UI Designer and Figma Specialist', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/interaction-design-foundation-ui-designer-and-figma-specialist'}
# {'company': 'Lemon.io', 'title': 'Senior Full-stack PHP&React Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/UK Only/Canada Only/Asia Only/Oceania Only', 'company_url': 'https://weworkremotely.com//top-remote-companies'}
# {'company': 'Duet, Inc.', 'title': 'Senior Software Engineer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/duet-inc-senior-software-engineer-11'}
# {'company': 'GotSoccer, LLC', 'title': 'Rails Developer', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/gotsoccer-llc-rails-developer-3'}
# {'company': 'Proxify AB', 'title': 'Senior MS Power BI Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior DevOps Engineer (AWS)', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior DevOps Engineer (Azure, AWS, GCP)', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior DevOps Engineer (Azure)', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior Django Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior Mobile Developer (Cross-Platform)', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior Pimcore Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior Next.js Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior WordPress Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Proxify AB', 'title': 'Senior Flutter Developer', 'work_type': 'Full-Time', 'region': 'Latin America Only/Europe Only/EMEA Only', 'company_url': 'https://weworkremotely.com//job-seekers/account/login'}
# {'company': 'Storyteller', 'title': 'Delivery Manager', 'work_type': 'Full-Time', 'region': 'USA Only/Europe Only/UK Only/Canada Only', 'company_url': 'https://weworkremotely.com//remote-jobs/storyteller-delivery-manager'}
# {'company': 'Baymard Institute', 'title': 'Head of B2B Growth Marketing/Demand Generation', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/baymard-institute-head-of-b2b-growth-marketing-demand-generation'}
# {'company': 'Localize', 'title': 'Platform Reliability Engineer', 'work_type': 'Full-Time', 'region': 'USA Only', 'company_url': 'https://weworkremotely.com//remote-jobs/localize-platform-reliability-engineer'}
# {'company': 'G2i Inc.', 'title': 'Backend Go Developer - Remote', 'work_type': 'Full-Time', 'region': 'Latin America Only', 'company_url': 'https://weworkremotely.com//top-remote-companies'}
# {'company': 'Ventures Together', 'title': 'Senior EA', 'work_type': 'Full-Time', 'region': 'Europe Only/UK Only/Africa Only', 'company_url': 'https://weworkremotely.com//remote-jobs/ventures-together-senior-ea'}
# {'company': 'Vidalytics', 'title': 'Customer Happiness Lead (SaaS Tech Support)', 'work_type': 'Full-Time', 'region': 'Latin America Only/Americas Only', 'company_url': 'https://weworkremotely.com//remote-jobs/vidalytics-customer-happiness-lead-saas-tech-support'}
# {'company': 'Fluro', 'title': 'Senior Infrastructure Engineer', 'work_type': 'Full-Time', 'region': 'Europe Only', 'company_url': 'https://weworkremotely.com//remote-jobs/fluro-senior-infrastructure-engineer'}
# {'company': 'Great Good Venture Studio', 'title': 'Sales & Client Manager for Relocation Agency (Thailand based role)', 'work_type': 'Full-Time', 'region': 'Anywhere in the World', 'company_url': 'https://weworkremotely.com//remote-jobs/great-good-venture-studio-sales-client-manager-for-relocation-agency-thailand-based-role'}
# {'company': 'UserEvidence', 'title': 'Senior Full-stack Engineer (Rails)', 'work_type': 'Full-Time', 'region': 'Latin America Only', 'company_url': 'https://weworkremotely.com//remote-jobs/userevidence-senior-full-stack-engineer-rails-1'}
# {'company': 'Greenlight Media Pte Ltd', 'title': 'Operations Manager', 'work_type': 'Full-Time', 'region': 'Europe Only/UK Only/Asia Only/Oceania Only', 'company_url': 'https://weworkremotely.com//remote-jobs/greenlight-media-pte-ltd-operations-manager'}
# {'company': 'Web3 Jobs', 'title': 'Senior Ruby on Rails Developer', 'work_type': 'Full-Time', 'region': 'USA Only', 'company_url': 'https://weworkremotely.com//remote-jobs/web3-jobs-senior-ruby-on-rails-developer'}

# %% [markdown]
# ### 4. 몇페이지 까지 있는지 확인하기

# %%
page_url = 'https://weworkremotely.com/remote-full-time-jobs?page=1'
page_response = requests.get(page_url)
page_soup = BeautifulSoup(page_response.content, 'html.parser')

# %%
page_num = page_soup.find("span", class_="pages-container with_next_last")\
                    .find_all("span")

# %%
def get_page_num():
    page_url = 'https://weworkremotely.com/remote-full-time-jobs?page=1'
    page_response = requests.get(page_url)
    page_soup = BeautifulSoup(page_response.content, 'html.parser')
    page_num = page_soup.find("span", class_="pages-container with_next_last")\
                    .find_all("span")
    return len(page_num)

# %%
max_page_num = get_page_num()

# %% [markdown]
# ### 5. 데이터 파싱 함수 만들기

# %%
def parsing_data(url):

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    jobs = soup.find('section', class_='jobs').find_all('li')[:-1]

    total_jobs = []
    for job in jobs:
        company = job.find("span", class_="company").text
        title = job.find("span", class_="title").text
        work_type = job.find_all("span", class_="company")[1].text
        region = job.find("span", class_="region").text
        company_url = f'https://weworkremotely.com{job.find_all("a")[1]["href"]}'

        job_data = {
            'company': company,
            'title': title,
            'work_type': work_type,
            'region': region,
            'company_url': company_url
        }
        total_jobs.append(job_data)

    return total_jobs

# %%
total_data = []
for num in range(max_page_num):
    print(num+1)
    url = f'https://weworkremotely.com/remote-full-time-jobs?page={num+1}'
    result = parsing_data(url)
    total_data.extend(result)
# Out:
# 1
# 2
# 3

# %%
result_df = pd.DataFrame(total_data)
result_df
# Out:
#                         company  \
# 0                      Lemon.io
# 1                     RebelCode
# 2                     SocialHub
# 3                     SocialHub
# 4    BURNETTE, DOBSON & PINCHAK
# ..                          ...
# 127          Sanctuary Computer
# 128                    Salesmsg
# 129                 Flag Theory
# 130           BBE Marketing Inc
# 131                    Maids.cc
#
#                                                  title  work_type  \
# 0                     Senior Java Full-stack Developer  Full-Time
# 1                                       Lead Developer  Full-Time
# 2           Full Stack Developer - Remote/SaaS (m/f/d)  Full-Time
# 3    Backend Javascript / Node.js Developer - Remot...  Full-Time
# 4                        Executive Assitant to the CEO  Full-Time
# ..                                                 ...        ...
# 127                   Experienced Full-stack Developer  Full-Time
# 128             Head of Customer Success (SaaS) 🤝🏻 💸 😄  Full-Time
# 129  Client Onboarding for Corporate Services (Bank...  Full-Time
# 130                     Full-Stack Wordpress Developer  Full-Time
# 131                                  Business Analyst   Full-Time
#
#                                                 region  \
# 0    Latin America Only/Europe Only/UK Only/Canada ...
# 1                                Anywhere in the World
# 2                                Anywhere in the World
# 3                                Anywhere in the World
# 4                                Anywhere in the World
# ..                                                 ...
# 127                              Anywhere in the World
# 128                              Anywhere in the World
# 129                                        Europe Only
# 130                              Anywhere in the World
# 131                              Anywhere in the World
#
#                                            company_url
# 0      https://weworkremotely.com/top-remote-companies
# 1    https://weworkremotely.com/remote-jobs/rebelco...
# 2    https://weworkremotely.com/remote-jobs/socialh...
# 3    https://weworkremotely.com/remote-jobs/socialh...
# 4    https://weworkremotely.com/remote-jobs/burnett...
# ..                                                 ...
# 127  https://weworkremotely.com/remote-jobs/sanctua...
# 128  https://weworkremotely.com/remote-jobs/salesms...
# 129  https://weworkremotely.com/remote-jobs/flag-th...
# 130  https://weworkremotely.com/remote-jobs/bbe-mar...
# 131  https://weworkremotely.com/remote-jobs/maids-c...
#
# [132 rows x 5 columns]

# %% [markdown]
# ## challenge

# %%
challenge_url = "https://remoteok.com/remote-python-jobs"
response = requests.get(challenge_url)

## 해당 URL을 요청했을때 정상적으로 응답이 왔는지 확인
if response.status_code == 200:
    print("성공")
else :
    print("실패")

response.content
# Out:
# 실패
# b'<html>\n<head><title>429 Too Many Requests</title></head>\n<body>\n<center><h1>429 Too Many Requests</h1></center>\n<hr><center>nginx</center>\n</body>\n</html>\n'

# %%
header = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36"
}

# %%
response = requests.get(challenge_url, headers= header)
if response.status_code == 200:
    print("성공")
else :
    print("실패")

response.content
# Out:
# 성공
# b'<!doctype html><html lang="en" class="  pageType-tag  remoteok    minimize-header   catch-emails-enabled"> <head>\n<script>\n\t\t\t\t\t\t// <auto detect user\'s OS dark mode if dark_mode not set before>\n\t\t\t\t\t\t\t//\n\t\t\t\t\t\t\t// this is vanilla JS and put here to block rendering so it\'s fast and \n\t\t\t\t\t\t\t// doesn\'t flash switching from light to dark mode if OS detected\n\t\t\t\t\t\t\t//\n\t\t\t\t\t\t\tfunction autoDetectOSDarkMode() {\n\t\t\t\t\t\t\t\tconsole.log(\'=====================\');\n\t\t\t\t\t\t\t\tconsole.log(\'autoDetectOSDarkMode\');\n\t\t\t\t\t\t\t\tvar cname=\'dark_mode\'\n\t\t\t\t\t\t\t\tvar name = cname + "=";\n\t\t\t\t\t\t\t\tvar ca = document.cookie.split(\';\');\n\t\t\t\t\t\t\t\tvar dark_mode=\'\';\n\t\t\t\t\t\t\t\tfor(var i=0; i<ca.length; i++) {\n\t\t\t\t\t\t\t\t\tvar c = ca[i];\n\t\t\t\t\t\t\t\t\twhile (c.charAt(0)==\' \') c = c.substring(1);\n\t\t\t\t\t\t\t\t\tif (c.indexOf(name) != -1) {\n\t\t\t\t\t\t\t\t\t\tdark_mode=c.substring(name.length,c.length);\n\t\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\t}\n\n\t\t\t\t\t\t\t\tconsole.log(\'cookie dark_mode = \'+dark_mode);\n\t\t\t\t\t\t\t\tconsole.log(\'matchmedia=\'+window.matchMedia(\'(prefers-color-scheme: dark)\').matches);\n\n\t\t\t\t\t\t\t\tif(\n\t\t\t\t\t\t\t\t\tdark_mode==\'\'\n\t\t\t\t\t\t\t\t\t\t&&\n\t\t\t\t\t\t\t\t\twindow.matchMedia(\'(prefers-color-scheme: dark)\').matches\n\t\t\t\t\t\t\t\t) {\n\t\t\t\t\t\t\t\t\tconsole.log(\'OS dark mode detected or dark_mode set in cookie already, set dark in class\');\n\t\t\t\t\t\t\t\t\tdocument.querySelector(\'html\').classList.add(\'dark\');\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\telse if(\n\t\t\t\t\t\t\t\t\tdark_mode==\'\'\n\t\t\t\t\t\t\t\t\t\t&&\n\t\t\t\t\t\t\t\t\twindow.matchMedia(\'(prefers-color-scheme: light)\').matches\n\t\t\t\t\t\t\t\t) {\n\t\t\t\t\t\t\t\t\tconsole.log(\'OS light mode detected\');\n\t\t\t\t\t\t\t\t\tdocument.querySelector(\'html\').classList.remove(\'dark\');\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\telse if(dark_mode==\'on\' || dark_mode==\'off\') {\n\t\t\t\t\t\t\t\t\t// user has dark mode cookie set, do nothing because PHP handles it in <html>\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\telse {\n\t\t\t\t\t\t\t\t\t// user has no dark mode cookie set, and isn\'t OS dark mode either, remove dark mode\n\t\t\t\t\t\t\t\t\tconsole.log(\'OS dark mode NOT detected\');\n\t\t\t\t\t\t\t\t\tdocument.querySelector(\'html\').classList.remove(\'dark\');\n\t\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t}\n\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t// run on load\n\t\t\t\t\t\t\t// 2024-01-07 disable os dark mode cause let\'s go for fresh vibe for 2024\n\t\t\t\t\t\t\t//autoDetectOSDarkMode();\n\n\t\t\t\t\t\t\t// run on change\n\t\t\t\t\t\t\twindow.matchMedia(\'(prefers-color-scheme: dark)\').addEventListener(\'change\', event => {\n\t\t\t\t\t\t\t    autoDetectOSDarkMode();\n\t\t\t\t\t\t\t});\n\t\t\t\t\t\t// </auto detect user\'s OS dark mode if dark_mode not set before>\n\t\t\t\t\t</script>\n<link rel="stylesheet" href="/global.css?1708185059">\n<script>\n\t\t\t\t\t\t\t\t\t\t\t\t\tvar userIsAdmin=false;\n\t\t\t\t\t\t\t\t\t\t\t</script>\n<meta charset="UTF-8">\n<title>Remote Python Jobs with great benefits and pay</title>\n<meta name="description" content="Browse 20+ Remote  Python Jobs in May 2024 at companies like Ethena, Syntropy and Chainstack with salaries from $30,000/year to $140,000/year working as a Infrastructure Engineer, Developer Relations Engineer or Senior Web3 Engineer. Last post 22 days">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta http-equiv="Content-Language" content="en-US">\n<link rel="search" type="application/opensearchdescription+xml" title="Remote OK" href="/opensearch.xml">\n<meta name="google" value="notranslate">\n<meta name="twitter:label1" value="Positions"><meta name="twitter:data1" value="Data Engineer, Software Engineer and Business Operations Analyst"> <meta name="twitter:label2" value="Companies"><meta name="twitter:data2" value="Ethena, Syntropy and Chainstack">\n<link ...

# %%
soup = BeautifulSoup(response.content, 'html.parser')
